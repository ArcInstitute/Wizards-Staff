# %% [markdown]
# # Setup

# %%
# import
import os
from wizards_staff import Orb
# Out:
# 2024-11-11 09:57:37.944208: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-11-11 09:57:38.148076: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-11 09:57:38.211263: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-11 09:57:38.238205: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-11 09:57:38.401178: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX512_FP16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-11 09:57:40.852778: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# set variables
#results_folder = '/large_storage/multiomics/projects/lizard_wizard/test_output/moldev-2d'
results_folder = '/large_storage/konermann/public/calcium_imaging_files/'
metadata_path = os.path.join(results_folder, 'metadata.csv')
output_dir = 'tmp/output'

# %% [markdown]
# # Create Orb object

# %%
# initialize orb
orb = Orb(results_folder, metadata_path)
# Out:
# Loading metadata from: /large_storage/konermann/public/calcium_imaging_files/metadata.csv
# Categorizing files...
# WARNING: No 'mask' files found for samples: 20240628-_5wk_CoCul_B-D_4AP_aB_Stream_B05_s3_FITC_full, 20240628-_5wk_CoCul_B-D_4AP_aB_Stream_B05_s1_FITC_full, 20240628-_5wk_CoCul_B-D_4AP_aB_Stream_B05_s2_FITC_full

# %% [markdown]
# ## View into the orb

# %%
# all input files merged with metadata
orb.input
# Out:
#                                                Sample       DataItem  \
# 0   20240628-_5wk_CoCul_B-D_4AP_aB_Stream_B05_s1_F...  minprojection
# 1   20240628-_5wk_CoCul_B-D_4AP_aB_Stream_B05_s1_F...          cnm_S
# 2   20240628-_5wk_CoCul_B-D_4AP_aB_Stream_B05_s1_F...          cnm_C
# 3   20240628-_5wk_CoCul_B-D_4AP_aB_Stream_B05_s1_F...        cnm_idx
# 4   20240628-_5wk_CoCul_B-D_4AP_aB_Stream_B05_s1_F...          cnm_A
# 5   20240628-_5wk_CoCul_B-D_4AP_aB_Stream_B05_s1_F...        dff_dat
# 6   20240628-_5wk_CoCul_B-D_4AP_aB_Stream_B05_s1_F...          f_dat
# 7   20240628-_5wk_CoCul_B-D_4AP_aB_Stream_B05_s1_F...    df_f0_graph
# 8   20240628-_5wk_CoCul_B-D_4AP_aB_Stream_B05_s2_F...  minprojection
# 9   20240628-_5wk_CoCul_B-D_4AP_aB_Stream_B05_s2_F...        cnm_idx
# 10  20240628-_5wk_CoCul_B-D_4AP_aB_Stream_B05_s2_F...          cnm_S
# 11  20240628-_5wk_CoCul_B-D_4AP_aB_Stream_B05_s2_F...          cnm_C
# 12  20240628-_5wk_CoCul_B-D_4AP_aB_Stream_B05_s2_F...          cnm_A
# 13  20240628-_5wk_CoCul_B-D_4AP_aB_Stream_B05_s2_F...          f_dat
# 14  20240628-_5wk_CoCul_B-D_4AP_aB_Stream_B05_s2_F...        dff_dat
# 15  20240628-_5wk_CoCul_B-D_4AP_aB_Stream_B05_s2_F...    df_f0_graph
# 16  20240628-_5wk_CoCul_B-D_4AP_aB_Stream_B05_s3_F...  minprojection
# 17  20240628-_5wk_CoCul_B-D_4AP_aB_Stream_B05_s3_F...          cnm_C
# 18  20240628-_5wk_CoCul_B-D_4AP_aB_Stream_B05_s3_F...        cnm_idx
# 19  20240628-_5wk_CoCul_B-D_4AP_aB_Stream_B05_s3_F...          cnm_S
# 20  20240628-_5wk_CoCul_B-D_4AP_aB_Stream_B05_s3_F...          cnm_A
# 21  20240628-_5wk_CoCul_B-D_4AP_aB_Stream_B05_s3_F...    df_f0_graph
# 22  20240628-_5wk_CoCul_B-D_4AP_aB_Stream_B05_s3_F...        dff_dat
# 23  20240628-_5wk_CoCul_B-D_4AP_aB_Stream_B05_s3_F...          f_dat
#
#                                              FilePath Well  Frate
# 0   /large_storage/konermann/public/calcium_imagin...  B05   25.0
# 1   /large_storage/konermann/public/calcium_imagin...  B05   25.0
# 2   /large_storage/konermann/public/calcium_imagin...  B05   25.0
# 3   /large_storage/konermann/public/calcium_imagin...  B05   25.0
# 4   /large_storage/konermann/public/calcium_imagin...  B05   25.0
# 5   /large_storage/konermann/public/calcium_imagin...  B05   25.0
# 6   /large_storage/konermann/public/calcium_imagin...  B05   25.0
# 7   /large_storage/konermann/public/calcium_imagin...  B05   25.0
# 8   /large_storage/konermann/public/calcium_imagin...  B05   25.0
# 9   /large_storage/konermann/public/calcium_imagin...  B05   25.0
# 10  /large_storage/konermann/public/calcium_imagin...  B05   25.0
# 11  /large_storage/konermann/public/calcium_imagin...  B05   25.0
# 12  /large_storage/konermann/public/calcium_imagin...  B05   25.0
# 13  /large_storage/konermann/public/calcium_imagin...  B05   25.0
# 14  /large_storage/konermann/public/calcium_imagin...  B05   25.0
# 15  /large_storage/konermann/public/calcium_imagin...  B05   25.0
# 16  /large_storage/konermann/public/calcium_imagin...  B05   25.0
# 17  /large_storage/konermann/public/calcium_imagin...  B05   25.0
# 18  /large_storage/konermann/public/calcium_imagin...  B05   25.0
# 19  /large_storage/konermann/public/calcium_imagin...  B05   25.0
# 20  /large_storage/konermann/public/calcium_imagin...  B05   25.0
# 21  /large_storage/konermann/public/calcium_imagin...  B05   25.0
# 22  /large_storage/konermann/public/calcium_imagin...  B05   25.0
# 23  /large_storage/konermann/public/calcium_imagin...  B05   25.0

# %% [markdown]
# # Analyze data

# %%
# run all (in parallel)
## provide a group name (matching a metadata column) to include the pairwise correlation analysis
orb.run_all(group_name="Well", show_plots=False, save_files=False, output_dir=output_dir)
# Out:
# Shattering the orb and processing each shard...:   0%|          | 0/3 [00:00<?, ?it/s]
# /home/nickyoungblut/miniforge3/envs/wizards-staff/lib/python3.11/site-packages/caiman/source_extraction/cnmf/deconvolution.py:1047: RuntimeWarning: divide by zero encountered in log
#   'logmexp': lambda Pxx_ind: np.sqrt(np.exp(np.mean(np.log(Pxx_ind / 2))))
# WARNING: cannot access local variable 'mask_metrics' where it is not associated with a value
# /home/nickyoungblut/miniforge3/envs/wizards-staff/lib/python3.11/site-packages/caiman/source_extraction/cnmf/deconvolution.py:1047: RuntimeWarning: divide by zero encountered in log
#   'logmexp': lambda Pxx_ind: np.sqrt(np.exp(np.mean(np.log(Pxx_ind / 2))))
# WARNING: cannot access local variable 'mask_metrics' where it is not associated with a value
# /home/nickyoungblut/miniforge3/envs/wizards-staff/lib/python3.11/site-packages/caiman/source_extraction/cnmf/deconvolution.py:1047: RuntimeWarning: divide by zero encountered in log
#   'logmexp': lambda Pxx_ind: np.sqrt(np.exp(np.mean(np.log(Pxx_ind / 2))))
# WARNING: cannot access local variable 'mask_metrics' where it is not associated with a value
# /home/nickyoungblut/miniforge3/envs/wizards-staff/lib/python3.11/site-packages/numpy/lib/function_base.py:2895: RuntimeWarning: invalid value encountered in divide
#   return c / c
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 3
#       1 # run all (in parallel)
#       2 ## provide a group name (matching a metadata column) to include the pairwise correlation analysis
# ----> 3 orb.run_all(group_name="Well", show_plots=False, save_files=False, output_dir=output_dir)
#
# File ~/dev/python/Wizards-Staff/wizards_staff/wizards/orb.py:250, in Orb.run_all(self, *args, **kwargs)
#     246 """
#     247 Runs all data processing steps.
#     248 """
#     249 # run all processing steps
# --> 250 ws_run_all(self, *args, **kwargs)
#
# File ~/dev/python/Wizards-Staff/wizards_staff/wizards/cauldron.py:111, in run_all(orb, frate, zscore_threshold, percentage_threshold, p_th, min_clusters, max_clusters, random_seed, group_name, poly, size_threshold, show_plots, save_files, output_dir, threads, debug, **kwargs)
#     109 # Run PWC analysis if group_name is provided
#     110 if group_name:
# --> 111     orb.run_pwc(
#     112         group_name,
#     113         poly = poly,
#     114         p_th = p_th,
#     115         size_threshold = size_threshold,
#     116         show_plots = show_plots,
#     117         save_files = save_files,
#     118         output_dir = output_dir,
#     119         **kwargs
#     120     )
#     121 else:
#     122     orb._logger.warning('Skipping PWC analysis as group_name is not provided.')
#
# File ~/dev/python/Wizards-Staff/wizards_staff/wizards/orb.py:258, in Orb.run_pwc(self, *args, **kwargs)
#     254 """
#     255 Runs pairwise correlation analysis on all samples.
#     256 """
#     257 # run PWC on each sample
# --> 258 ws_run_pwc(self, *args, **kwargs)
#
# File ~/dev/python/Wizards-Staff/wizards_staff/pwc.py:92, in run_pwc(orb, group_name, poly, p_th, size_threshold, pdeg, lw, lwp, psz, show_plots, save_files, output_dir)
#      89 filtered_d_k_in_groups = filter_group_keys(d_k_in_groups, d_dff, d_nspIDs)
#      91 # Calculate pairwise correlation means for groups
# ---> 92 d_mn_pwc, d_mn_pwc_inter, d_mn_pwc_intra = calc_pwc_mn(
#      93     filtered_d_k_in_groups, d_dff, d_nspIDs,
#      94     dff_cut=0.0, norm_corr=False
#      95 )
#      97 # Convert dictionaries to DataFrames
#      98 df_mn_pwc = pd.DataFrame.from_dict(d_mn_pwc, orient='index').transpose()
#
# File ~/dev/python/Wizards-Staff/wizards_staff/pwc.py:201, in calc_pwc_mn(d_k_in_groups, d_dff, d_nspIDs, dff_cut, norm_corr)
#     199 r = np.corrcoef(tmp_dat_filt)
#     200 r = np.nan_to_num(r)  # Replace NaNs with zeros
# --> 201 np.fill_diagonal(r, 0)  # Set diagonal to zero
#     203 # Apply Fisher's z-transformation if normalization is requested
#     204 if norm_corr:
#
# File ~/miniforge3/envs/wizards-staff/lib/python3.11/site-packages/numpy/lib/index_tricks.py:899, in fill_diagonal(a, val, wrap)
#     787 """Fill the main diagonal of the given array of any dimensionality.
#     788
#     789 For an array `a` with ``a.ndim >= 2``, the diagonal is the list of
#    (...)
#     896 on the flip function.
#     897 """
#     898 if a.ndim < 2:
# --> 899     raise ValueError("array must be at least 2-d")
#     900 end = None
#     901 if a.ndim == 2:
#     902     # Explicit, fast formula for the common case.  For 2-d arrays, we
#     903     # accept rectangular ones.
#
# ValueError: array must be at least 2-d

# %%
# write out results
for result_name,result_data in orb.results:
    print(result_name)
    print(result_data)
    print('---')
# Out:
# rise_time_data
# None
# ---
# fwhm_data
# None
# ---
# frpm_data
# None
# ---
# mask_metrics_data
# None
# ---
# silhouette_scores_data
# None
# ---
# df_mn_pwc
# None
# ---
# df_mn_pwc_intra
# None
# ---
# df_mn_pwc_inter
# None
# ---

# %% [markdown]
# # sessionInfo

# %%
# !mamba list
# Out:
# # packages in environment at /home/nickyoungblut/miniforge3/envs/wizards-staff:
# #
# # Name                    Version                   Build  Channel
# _libgcc_mutex             0.1                 conda_forge    conda-forge
# _openmp_mutex             4.5                       2_gnu    conda-forge
# absl-py                   2.1.0                    pypi_0    pypi
# aiohappyeyeballs          2.4.3              pyhd8ed1ab_0    conda-forge
# aiohttp                   3.10.10         py311h2dc5d0c_0    conda-forge
# aiosignal                 1.3.1              pyhd8ed1ab_0    conda-forge
# asciitree                 0.3.3                    pypi_0    pypi
# asttokens                 2.4.1                    pypi_0    pypi
# astunparse                1.6.3                    pypi_0    pypi
# attrs                     24.2.0             pyh71513ae_0    conda-forge
# bleach                    6.1.0                    pypi_0    pypi
# bokeh                     3.5.2                    pypi_0    pypi
# brotli-python             1.1.0           py311hfdbb021_2    conda-forge
# bzip2                     1.0.8                h4bc722e_7    conda-forge
# c-ares                    1.34.1               heb4867d_0    conda-forge
# ca-certificates           2024.8.30            hbcca054_0    conda-forge
# cachetools                5.5.0              pyhd8ed1ab_0    conda-forge
# caiman                    1.11.3                   pypi_0    pypi
# certifi                   2024.8.30          pyhd8ed1ab_0    conda-forge
# cffi                      1.17.1          py311hf29c0ef_0    conda-forge
# charset-normalizer        3.3.2                    pypi_0    pypi
# colorama                  0.4.6              pyhd8ed1ab_0    conda-forge
# colorcet                  3.1.0                    pypi_0    pypi
# comm                      0.2.2                    pypi_0    pypi
# contourpy                 1.3.0                    pypi_0    pypi
# cryptography              43.0.1          py311hafd3f86_0    conda-forge
# cycler                    0.12.1                   pypi_0    pypi
# debugpy                   1.8.5                    pypi_0    pypi
# decorator                 5.1.1                    pypi_0    pypi
# entrypoints               0.4                      pypi_0    pypi
# exceptiongroup            1.2.2              pyhd8ed1ab_0    conda-forge
# executing                 2.1.0                    pypi_0    pypi
# fasteners                 0.19                     pypi_0    pypi
# flatbuffers               24.3.25                  pypi_0    pypi
# fonttools                 4.53.1                   pypi_0    pypi
# frozenlist                1.4.1           py311h9ecbd09_1    conda-forge
# gast                      0.6.0                    pypi_0    pypi
# google-api-core           2.21.0             pyhd8ed1ab_0    conda-forge
# google-auth               2.35.0             pyhff2d567_0    conda-forge
# google-cloud-core         2.4.1              pyhd8ed1ab_0    conda-forge
# google-cloud-storage      2.18.2             pyhff2d567_0    conda-forge
# google-crc32c             1.1.2           py311h0973507_6    conda-forge
# google-pasta              0.2.0                    pypi_0    pypi
# google-resumable-media    2.7.2              pyhd8ed1ab_1    conda-forge
# googleapis-common-protos  1.65.0             pyhd8ed1ab_0    conda-forge
# greenlet                  3.1.1                    pypi_0    pypi
# grpcio                    1.66.1                   pypi_0    pypi
# h2                        4.1.0              pyhd8ed1ab_0    conda-forge
# h5py                      3.11.0                   pypi_0    pypi
# hdmf                      3.14.4                   pypi_0    pypi
# holoviews                 1.19.1                   pypi_0    pypi
# hpack                     4.0.0              pyh9f0ad1d_0    conda-forge
# hyperframe                6.0.1              pyhd8ed1ab_0    conda-forge
# idna                      3.10               pyhd8ed1ab_0    conda-forge
# imageio                   2.35.1                   pypi_0    pypi
# iniconfig                 2.0.0              pyhd8ed1ab_0    conda-forge
# ipykernel                 6.29.5                   pypi_0    pypi
# ipyparallel               8.8.0                    pypi_0    pypi
# ipython                   8.27.0                   pypi_0    pypi
# ipywidgets                8.1.5                    pypi_0    pypi
# jedi                      0.19.1                   pypi_0    pypi
# jinja2                    3.1.4                    pypi_0    pypi
# joblib                    1.4.2                    pypi_0    pypi
# jsonschema                4.23.0                   pypi_0    pypi
# jsonschema-specifications 2023.12.1                pypi_0    pypi
# jupyter-client            8.6.3                    pypi_0    pypi
# jupyter-core              5.7.2                    pypi_0    pypi
# jupyterlab-widgets        3.0.13                   pypi_0    pypi
# keras                     3.5.0                    pypi_0    pypi
# kiwisolver                1.4.7                    pypi_0    pypi
# lazy-loader               0.4                      pypi_0    pypi
# ld_impl_linux-64          2.40                 hf3520f5_7    conda-forge
# libabseil                 20240116.2      cxx17_he02047a_1    conda-forge
# libclang                  18.1.1                   pypi_0    pypi
# libcrc32c                 1.1.2                h9c3ff4c_0    conda-forge
# libexpat                  2.6.3                h5888daf_0    conda-forge
# libffi                    3.4.2                h7f98852_5    conda-forge
# libgcc                    14.1.0               h77fa898_1    conda-forge
# libgcc-ng                 14.1.0               h69a702a_1    conda-forge
# libgomp                   14.1.0               h77fa898_1    conda-forge
# libgrpc                   1.62.2               h15f2491_0    conda-forge
# libnsl                    2.0.1                hd590300_0    conda-forge
# libprotobuf               4.25.3               hd5b35b9_1    conda-forge
# libre2-11                 2023.09.01           h5a48ba9_2    conda-forge
# libsqlite                 3.46.1               hadc24fc_0    conda-forge
# libstdcxx                 14.1.0               hc0a3c3a_1    conda-forge
# libstdcxx-ng              14.1.0               h4852527_1    conda-forge
# libuuid                   2.38.1               h0b41bf4_0    conda-forge
# libxcrypt                 4.4.36               hd590300_1    conda-forge
# libzlib                   1.3.1                h4ab18f5_1    conda-forge
# linkify-it-py             2.0.3                    pypi_0    pypi
# markdown                  3.7                      pypi_0    pypi
# markdown-it-py            3.0.0                    pypi_0    pypi
# markupsafe                2.1.5                    pypi_0    pypi
# matplotlib                3.9.2                    pypi_0    pypi
# matplotlib-inline         0.1.7                    pypi_0    pypi
# mdit-py-plugins           0.4.2                    pypi_0    pypi
# mdurl                     0.1.2                    pypi_0    pypi
# ml-dtypes                 0.4.1                    pypi_0    pypi
# multidict                 6.1.0           py311h9ecbd09_0    conda-forge
# namex                     0.0.8                    pypi_0    pypi
# ncurses                   6.5                  he02047a_1    conda-forge
# nest-asyncio              1.6.0                    pypi_0    pypi
# networkx                  3.3                      pypi_0    pypi
# numcodecs                 0.13.0                   pypi_0    pypi
# numpy                     1.26.4                   pypi_0    pypi
# opencv-python             4.10.0.84                pypi_0    pypi
# openssl                   3.3.2                hb9d3cd8_0    conda-forge
# opt-einsum                3.3.0                    pypi_0    pypi
# optree                    0.12.1                   pypi_0    pypi
# packaging                 24.1               pyhd8ed1ab_0    conda-forge
# pandas                    2.2.2                    pypi_0    pypi
# panel                     1.5.0                    pypi_0    pypi
# param                     2.1.1                    pypi_0    pypi
# parso                     0.8.4                    pypi_0    pypi
# peakutils                 1.3.5                    pypi_0    pypi
# pexpect                   4.9.0                    pypi_0    pypi
# pillow                    10.4.0                   pypi_0    pypi
# pims                      0.7                      pypi_0    pypi
# pip                       24.2               pyh8b19718_1    conda-forge
# platformdirs              4.3.6                    pypi_0    pypi
# pluggy                    1.5.0              pyhd8ed1ab_0    conda-forge
# prompt-toolkit            3.0.47                   pypi_0    pypi
# propcache                 0.2.0           py311h9ecbd09_2    conda-forge
# proto-plus                1.23.0             pyhd8ed1ab_0    conda-forge
# protobuf                  4.25.4                   pypi_0    pypi
# psutil                    6.0.0                    pypi_0    pypi
# psycopg2-binary           2.9.9                    pypi_0    pypi
# ptyprocess                0.7.0                    pypi_0    pypi
# pure-eval                 0.2.3                    pypi_0    pypi
# pyasn1                    0.6.1              pyhd8ed1ab_1    conda-forge
# pyasn1-modules            0.4.1              pyhd8ed1ab_0    conda-forge
# pycparser                 2.22               pyhd8ed1ab_0    conda-forge
# pygments                  2.18.0                   pypi_0    pypi
# pynwb                     2.8.2                    pypi_0    pypi
# pyopenssl                 24.2.1             pyhd8ed1ab_2    conda-forge
# pyparsing                 3.1.4                    pypi_0    pypi
# pypika                    0.48.9                   pypi_0    pypi
# pysocks                   1.7.1              pyha2e5f31_6    conda-forge
# pytest                    8.3.3              pyhd8ed1ab_0    conda-forge
# python                    3.11.10         hc5c86c4_0_cpython    conda-forge
# python-dateutil           2.9.0.post0              pypi_0    pypi
# python-dotenv             1.0.1                    pypi_0    pypi
# python_abi                3.11                    5_cp311    conda-forge
# pytz                      2024.2                   pypi_0    pypi
# pyu2f                     0.1.5              pyhd8ed1ab_0    conda-forge
# pyviz-comms               3.0.3                    pypi_0    pypi
# pyyaml                    6.0.2                    pypi_0    pypi
# pyzmq                     26.2.0                   pypi_0    pypi
# re2                       2023.09.01           h7f4b329_2    conda-forge
# readline                  8.2                  h8228510_1    conda-forge
# referencing               0.35.1                   pypi_0    pypi
# requests                  2.32.3             pyhd8ed1ab_0    conda-forge
# rich                      13.8.1                   pypi_0    pypi
# rpds-py                   0.20.0                   pypi_0    pypi
# rsa                       4.9                pyhd8ed1ab_0    conda-forge
# ruamel-yaml               0.18.6                   pypi_0    pypi
# ruamel-yaml-clib          0.2.8                    pypi_0    pypi
# scikit-image              0.24.0                   pypi_0    pypi
# scikit-learn              1.5.2                    pypi_0    pypi
# scipy                     1.14.1                   pypi_0    pypi
# setuptools                73.0.1             pyhd8ed1ab_0    conda-forge
# six                       1.16.0             pyh6c4a22f_0    conda-forge
# slicerator                1.1.0                    pypi_0    pypi
# sqlalchemy                2.0.35                   pypi_0    pypi
# stack-data                0.6.3                    pypi_0    pypi
# tensorboard               2.17.1                   pypi_0    pypi
# tensorboard-data-server   0.7.2                    pypi_0    pypi
# tensorflow                2.17.0                   pypi_0    pypi
# tensorflow-io-gcs-filesystem 0.37.1                   pypi_0    pypi
# termcolor                 2.4.0                    pypi_0    pypi
# threadpoolctl             3.5.0                    pypi_0    pypi
# tifffile                  2024.8.30                pypi_0    pypi
# tk                        8.6.13          noxft_h4845f30_101    conda-forge
# tomli                     2.0.2              pyhd8ed1ab_0    conda-forge
# tornado                   6.4.1                    pypi_0    pypi
# tqdm                      4.66.5                   pypi_0    pypi
# traitlets                 5.14.3                   pypi_0    pypi
# typing-extensions         4.12.2                   pypi_0    pypi
# tzdata                    2024.1                   pypi_0    pypi
# uc-micro-py               1.0.3                    pypi_0    pypi
# urllib3                   2.2.3              pyhd8ed1ab_0    conda-forge
# wcwidth                   0.2.13                   pypi_0    pypi
# webencodings              0.5.1                    pypi_0    pypi
# werkzeug                  3.0.4                    pypi_0    pypi
# wheel                     0.44.0             pyhd8ed1ab_0    conda-forge
# widgetsnbextension        4.0.13                   pypi_0    pypi
# wizards-staff             0.1.0                    pypi_0    pypi
# wrapt                     1.16.0                   pypi_0    pypi
# xyzservices               2024.9.0                 pypi_0    pypi
# xz                        5.2.6                h166bdaf_0    conda-forge
# yarl                      1.14.0          py311h9ecbd09_0    conda-forge
# zarr                      2.18.3                   pypi_0    pypi
# zstandard                 0.23.0          py311hbc35293_1    conda-forge
# zstd                      1.5.6                ha6fb4c9_0    conda-forge
